# %% [markdown]
# ## James Cage
# #### April 11, 2019
#
# The intent of this notebook is to take the file "world_countries.json" and extract a database of country names and IDs

# %%
import csv
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
# download countries geojson file
# !wget --quiet https://ibm.box.com/shared/static/cto2qv7nx6yq19logfcissyy4euo8lho.json -O world_countries.json
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
# Read the file into a Python string

with open('world_countries.json', "r") as file1:
    FileContent = file1.read()

# %%
# The following strings identify where the country names and ids 
# begin and end.

start_name = 'name'
end_name = '\"'
start_id = '\"id'
end_id = '\"' 


def mine(in_string, out_string):
    if len(in_string) < 20:
        return out_string
    s = in_string.find(start_name) + 7
    e = in_string.find(end_name, s)
    out_string += in_string[s:e]+","
    
    s = in_string.find(start_id, e) + 6
    e = in_string.find(end_id, s)
    out_string += in_string[s:e] + "\n"
    
    return mine(in_string[e:], out_string)

# %%
# Read in the json file, parse it, and save it as a CSV file

namesDB = "Country,ID\n"   # Define the file header

with open('world_names.csv', "w") as file2:
    file2.write(mine(FileContent, namesDB))
    
# Now read the CSV file back in and create a pandas dataframe
# The "round trip" proves the file is good.

df_names = pd.read_csv('world_names.csv')

# %% [markdown]
# ## Fixing the Immigration Data
# Open the immigration data and make all country names compatible with the json file (as stored in df_names)

# %%
# df_can = pd.read_excel('https://ibm.box.com/shared/static/lw190pt9zpy5bd1ptyg2aw15awomz9pu.xlsx',
#                      sheet_name='Canada by Citizenship',
#                      skiprows=range(20),
#                      skipfooter=2)

df_can = pd.read_excel('https://github.com/JamesDCage/31-31Canada01/blob/master/Canada2.xlsx?raw=true',
                     sheet_name='Canada by Citizenship',
                     skiprows=range(20),
                     skipfooter=2)

df_can.head(5)
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# 2  3623  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0     0
# 4     1     0     0     0     0     1     1
#
# [5 rows x 43 columns]

# %% [markdown]
# How many country names in df_can are not in our json file? What are those countries?
# Let's find out using Python sets.

# %%
missing = list(set(df_can.OdName) - set(df_names.Country))
len(missing)
# Out:
# 39

# %%
# 49 missing countries!! Can I just ignore these rows?
df_can_missing = df_can[df_can['OdName'].isin(missing)]
df_can_missing.sort_values(by=[2013], ascending=False).head(17)
# Out:
#            Type    Coverage                                          OdName  \
# 111  Immigrants  Foreigners                                       Mauritius
# 37   Immigrants  Foreigners  China, Hong Kong Special Administrative Region
# 147  Immigrants  Foreigners                Saint Vincent and the Grenadines
# 163  Immigrants  Foreigners                              State of Palestine
# 146  Immigrants  Foreigners                                     Saint Lucia
# 70   Immigrants  Foreigners                                         Grenada
# 156  Immigrants  Foreigners                                       Singapore
# 41   Immigrants  Foreigners                                           Congo
# 172  Immigrants  Foreigners       The former Yugoslav Republic of Macedonia
# 21   Immigrants  Foreigners                Bolivia (Plurinational State of)
# 15   Immigrants  Foreigners                                        Barbados
# 12   Immigrants  Foreigners                                         Bahamas
# 52   Immigrants  Foreigners                                        Dominica
# 13   Immigrants  Foreigners                                         Bahrain
# 38   Immigrants  Foreigners      China, Macao Special Administrative Region
# 6    Immigrants  Foreigners                             Antigua and Barbuda
# 40   Immigrants  Foreigners                                         Comoros
#
#      AREA                         AreaName  REG             RegName  DEV  \
# 111   903                           Africa  910      Eastern Africa  902
# 37    935                             Asia  906        Eastern Asia  902
# 147   904  Latin America and the Caribbean  915           Caribbean  902
# 163   935                             Asia  922        Western Asia  902
# 146   904  Latin America and the Caribbean  915           Caribbean  902
# 70    904  Latin America and the Caribbean  915           Caribbean  902
# 156   935                             Asia  920  South-Eastern Asia  902
# 41    903                           Africa  911       Middle Africa  902
# 172   908                           Europe  925     Southern Europe  901
# 21    904  Latin America and the Caribbean  931       South America  902
# 15    904  Latin America and the Caribbean  915           Caribbean  902
# 12    904  Latin America and the Caribbean  915           Caribbean  902
# 52    904  Latin America and the Caribbean  915           Caribbean  902
# 13    935                             Asia  922        Western Asia  902
# 38    935                             Asia  906        Eastern Asia  902
# 6     904  Latin America and the Caribbean  915           Caribbean  902
# 40    903                           Africa  910      Eastern Africa  902
#
#                 DevName  1980  ...  2004  2005  2006  2007  2008  2009  2010  \
# 111  Developing regions   306  ...   702   696   512   507   714   872  1455
# 37   Developing regions     0  ...   536   729   712   674   897   657   623
# 147  Developing regions   147  ...   294   343   383   579   434   511   434
# 163  Developing regions     0  ...   376   453   627   441   481   400   654
# 146  Developing regions    69  ...   110   185   190   255   298   257   249
# 70   Developing regions   154  ...   296   283   363   360   284   325   208
# 156  Developing regions   241  ...   311   392   298   690   734   366   805
# 41   Developing regions     2  ...   142   136   143    87    72    70    75
# 172   Developed regions     0  ...   443   285   256   211   191   198   188
# 21   Developing regions    44  ...    85   134   139   107   143   214   180
# 15   Developing regions   372  ...    90   111    97   130   134   125   121
# 12   Developing regions    26  ...    13    14    18    23    30    27    25
# 52   Developing regions   104  ...    50    59    72    79    60    59    43
# 13   Developing regions     0  ...    12    12    12    22     9    35    28
# 38   Developing regions     0  ...    21    21    32    16    12    21    21
# 6    Developing regions     0  ...    14    24    32    15    32    38    27
# 40   Developing regions     0  ...     6     5     7    11     3    19    22
#
#      2011  2012  2013
# 111  1146   799  1203
# 37    591   728   774
# 147   451   523   538
# 163   555   533   462
# 146   261   382   392
# 70    173   142   170
# 156   219   146   141
# 41     81    91   114
# 172   130   126   112
# 21     86    83   107
# 15     97   132    97
# 12     40    60    55
# 52     36    43    48
# 13     21    39    32
# 38     13    33    29
# 6      37    51    25
# 40     14    18    22
#
# [17 rows x 43 columns]

# %%
# Ignoring ALL of the rows would be a bad idea. 
# Iran alone contributes ~ 4% to the immigration total for that year.
# But many contribute less than 0.05% of the total in 2013. 
# Let's ignore those. Now create a list of countries we WON'T ignore.

threshold =  0.0005 * df_can[2013].sum()

df_can_missing[df_can_missing[2013] > threshold].OdName

# I'm okay with ignoring any row that contributes less than 0.1% of immigration 

# df_can['Total'] = df_can.iloc[:, 9:43].sum(axis=1)
# Out:
# 37     China, Hong Kong Special Administrative Region
# 70                                            Grenada
# 111                                         Mauritius
# 146                                       Saint Lucia
# 147                  Saint Vincent and the Grenadines
# 156                                         Singapore
# 163                                State of Palestine
# Name: OdName, dtype: object

# %% [markdown]
# Of the above, the following were not in the json file. They're all fairly low in the list.
#
# China, Hong Kong Special Administrative Region
# Grenada
# Mauritius
# Saint Lucia
# Saint Vincent and the Grenadines
# Singapore
# State of Palestine
#
#
# I saved the updated spreadsheet as 'Canada2.xlsx'

# %% [markdown]
# ### Fixing World Population Data
#
# Let's import world population data from the World Bank, and make sure that country names are compatible. Since we've (mostly) made the names in df_can compatible with the geojson file, then we can use df_names to check for & enforce compatibility with df_names.

# %%
df_world_pop = pd.read_excel('http://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=excel',
                     sheet_name='Data',
                     skiprows=range(3))
df_world_pop.head(2)
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
#
#         1961       1962       1963       1964       1965  ...        2009  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101453.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  28004331.0
#
#          2010        2011        2012        2013        2014        2015  \
# 0    101669.0    102053.0    102577.0    103187.0    103795.0    104341.0
# 1  28803167.0  29708599.0  30696958.0  31731688.0  32758020.0  33736494.0
#
#          2016        2017  2018
# 0    104822.0    105264.0   NaN
# 1  34656032.0  35530081.0   NaN
#
# [2 rows x 63 columns]

# %%
# Generate a list of columns we don't want, and then drop them.

bad_columns = list(df_world_pop.loc[:, 'Indicator Name':'1979'].columns) + \
              list(df_world_pop.loc[:, '2014':'2018'].columns)

df_world_pop.drop(bad_columns, axis=1, inplace=True)

# Rename the first column to match the column in df_can

df_world_pop.rename(columns={'Country Name':'Country'}, inplace=True)

df_world_pop.head()
# Out:
#        Country Country Code        1980        1981        1982        1983  \
# 0        Aruba          ABW     60096.0     60567.0     61345.0     62201.0
# 1  Afghanistan          AFG  13248370.0  13053954.0  12749645.0  12389269.0
# 2       Angola          AGO   8929900.0   9244507.0   9582156.0   9931562.0
# 3      Albania          ALB   2671997.0   2726056.0   2784278.0   2843960.0
# 4      Andorra          AND     36067.0     37500.0     39114.0     40867.0
#
#          1984        1985        1986        1987  ...        2004  \
# 0     62836.0     63026.0     62644.0     61833.0  ...     98737.0
# 1  12047115.0  11783050.0  11601041.0  11502761.0  ...  24118979.0
# 2  10277321.0  10609042.0  10921037.0  11218268.0  ...  18865716.0
# 3   2904429.0   2964762.0   3022635.0   3083605.0  ...   3026939.0
# 4     42706.0     44600.0     46517.0     48455.0  ...     76244.0
#
#          2005        2006        2007        2008        2009        2010  \
# 0    100031.0    100832.0    101220.0    101353.0    101453.0    101669.0
# 1  25070798.0  25893450.0  26616792.0  27294031.0  28004331.0  28803167.0
# 2  19552542.0  20262399.0  20997687.0  21759420.0  22549547.0  23369131.0
# 3   3011487.0   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0
# 4     78867.0     80991.0     82683.0     83861.0     84462.0     84449.0
#
#          2011        2012        2013
# 0    102053.0    102577.0    103187.0
# 1  29708599.0  30696958.0  31731688.0
# 2  24218565.0  25096150.0  25998340.0
# 3   2905195.0   2900401.0   2895092.0
# 4     83751.0     82431.0     80788.0
#
# [5 rows x 36 columns]

# %%
# How many countries in df_names do not have a matching entry in df_world_pop? And are they countries of interest?

missing = list(set(df_names.Country) - set(df_world_pop['Country Name']))
df_can_missing = df_can[df_can['OdName'].isin(missing)]
df_can_missing.sort_values(by=[2013], ascending=False).head()
# Out:
#            Type    Coverage                    OdName  AREA          AreaName  \
# 81   Immigrants  Foreigners                      Iran   935              Asia
# 185  Immigrants  Foreigners  United States of America   905  Northern America
# 140  Immigrants  Foreigners               South Korea   935              Asia
# 55   Immigrants  Foreigners                     Egypt   903            Africa
# 143  Immigrants  Foreigners                    Russia   908            Europe
#
#       REG           RegName  DEV             DevName  1980  ...  2004  2005  \
# 81   5501     Southern Asia  902  Developing regions  1172  ...  6348  5837
# 185   905  Northern America  901   Developed regions  9378  ...  6990  8394
# 140   906      Eastern Asia  902  Developing regions  1011  ...  5352  5832
# 55    912   Northern Africa  902  Developing regions   612  ...  2393  2496
# 143   923    Eastern Europe  901   Developed regions     0  ...  3989  3972
#
#      2006  2007   2008  2009  2010  2011  2012   2013
# 81   7480  6974   6475  6580  7477  7479  7534  11291
# 185  9613  9463  10190  8995  8142  7676  7891   8501
# 140  6215  5920   7294  5874  5537  4588  5316   4509
# 55   2190  2356   3347  3496  5982  4663  5555   4165
# 143  3117  2983   2690  2931  2288  1963  2079   2466
#
# [5 rows x 43 columns]

# %% [markdown]
# I see 17 countries, including big ones like Iran, the US, South Korea, etc.
#
# But here's a stroke of luck. The World Pop data has a "Country Code" that appears to be the same as the "ID" in df_names. If they are the same, then we can rename countries in df_world_pop to be compatible with the geojson file ... and we made the immigration data (more or less) compatible with that file above.
#
# To merge two dataframes in Pandas, it appears the column headings must be the same. Let's make that happen.

# %%
df_world_pop.rename(columns={'Country Code':'ID'}, inplace=True)
df_world_pop.head(2)
# Out:
#   Country Name   ID     Indicator Name Indicator Code       1960       1961  \
# 0        Aruba  ABW  Population, total    SP.POP.TOTL    54211.0    55438.0
# 1  Afghanistan  AFG  Population, total    SP.POP.TOTL  8996351.0  9166764.0
#
#         1962       1963       1964       1965  ...        2009        2010  \
# 0    56225.0    56695.0    57032.0    57360.0  ...    101453.0    101669.0
# 1  9345868.0  9533954.0  9731361.0  9938414.0  ...  28004331.0  28803167.0
#
#          2011        2012        2013        2014        2015        2016  \
# 0    102053.0    102577.0    103187.0    103795.0    104341.0    104822.0
# 1  29708599.0  30696958.0  31731688.0  32758020.0  33736494.0  34656032.0
#
#          2017  2018
# 0    105264.0   NaN
# 1  35530081.0   NaN
#
# [2 rows x 63 columns]

# %%
pd.merge(df_world_pop, df_names, on='ID')[['Country Name', 'Country']]
# Out:
#                     Country Name                      Country
# 0                    Afghanistan                  Afghanistan
# 1                         Angola                       Angola
# 2                        Albania                      Albania
# 3           United Arab Emirates         United Arab Emirates
# 4                      Argentina                    Argentina
# 5                        Armenia                      Armenia
# 6                      Australia                    Australia
# 7                        Austria                      Austria
# 8                     Azerbaijan                   Azerbaijan
# 9                        Burundi                      Burundi
# 10                       Belgium                      Belgium
# 11                         Benin                        Benin
# 12                  Burkina Faso                 Burkina Faso
# 13                    Bangladesh                   Bangladesh
# 14                      Bulgaria                     Bulgaria
# 15                   The Bahamas                  The Bahamas
# 16        Bosnia and Herzegovina       Bosnia and Herzegovina
# 17                       Belarus                      Belarus
# 18                        Belize                       Belize
# 19                       Bolivia                      Bolivia
# 20                        Brazil                       Brazil
# 21                        Brunei                       Brunei
# 22                        Bhutan                       Bhutan
# 23                      Botswana                     Botswana
# 24      Central African Republic     Central African Republic
# 25                        Canada                       Canada
# 26                   Switzerland                  Switzerland
# 27                         Chile                        Chile
# 28                         China                        China
# 29                   Ivory Coast                  Ivory Coast
# ..                           ...                          ...
# 138                      Somalia                      Somalia
# 139           Republic of Serbia           Republic of Serbia
# 140                     Suriname                     Suriname
# 141                     Slovakia                     Slovakia
# 142                     Slovenia                     Slovenia
# 143                       Sweden                       Sweden
# 144                    Swaziland                    Swaziland
# 145                        Syria                        Syria
# 146                         Chad                         Chad
# 147                         Togo                         Togo
# 148                     Thailand                     Thailand
# 149                   Tajikistan                   Tajikistan
# 150                 Turkmenistan                 Turkmenistan
# 151                   East Timor                   East Timor
# 152          Trinidad and Tobago          Trinidad and Tobago
# 153                      Tunisia                      Tunisia
# 154                       Turkey                       Turkey
# 155  United Republic of Tanzania  United Republic of Tanzania
# 156                       Uganda                       Uganda
# 157                      Ukraine                      Ukraine
# 158                      Uruguay                      Uruguay
# 159     United States of America     United States of America
# 160                   Uzbekistan                   Uzbekistan
# 161                    Venezuela                    Venezuela
# 162                      Vietnam                      Vietnam
# 163                      Vanuatu                      Vanuatu
# 164                        Yemen                        Yemen
# 165                 South Africa                 South Africa
# 166                       Zambia                       Zambia
# 167                     Zimbabwe                     Zimbabwe
#
# [168 rows x 2 columns]

# %%
# Out:
# 'Cameroon'

# %%
# So the ID is a way to match country names across databases. 
# Now let's change the country names in df_world_pop to the equivalents in df_names

df_names_ids = set(df_names.ID)
df_world_pop_ids = set(df_world_pop.ID)

for id in set(df_names.ID):

    if id in df_world_pop_ids:
        # Find the index of the row in df_names with this ID
        a = df_names.index[df_names['ID'] == id] 
        # Get the country name from this row
        country = df_names.at[int(list(a)[0]),'Country']
        # Find the index of the row in df_world_pop with this ID
        b = df_world_pop.index[df_world_pop['ID'] == id]
        # Set the country in df_world_pop equal to the name from df_names
        df_world_pop.at[int(list(b)[0]),'Country Name'] = country
        print("yes", end = " ")
    else:
        print("no", end = "<-----")
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
# no
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no

# %%
# How many countries in df_can don't have a matching entry in the population data?

# First create a list of IDs in df_names that are not in df_world_pop

not_in_world_pop = list(set(df_names.ID) - set(df_world_pop['Country Code']))

# Now display the country names to see if any are of interest.
df_names[df_names.ID.isin(not_in_world_pop)]
# Out:
#                                  Country   ID
# 6                             Antarctica  ATA
# 7    French Southern and Antarctic Lands  ATF
# 38                       Northern Cyprus  -99
# 54                      Falkland Islands  FLK
# 88                                Kosovo  -99
# 136                       Western Sahara  -99
# 139                          South Sudan  SDS
# 144                           Somaliland  -99
# 162                               Taiwan  TWN

# %% [markdown]
# Conclusion: If we

# %%
# Once again, let's sort these countries by 2013 immigration numbers.
# We'll change the names in the population db for the ones we need.

df_can_missing = df_can[df_can['OdName'].isin(missing)]
df_can_missing.sort_values(by=[2013], ascending=False).head(1)
# Out:
#           Type    Coverage OdName  AREA AreaName   REG        RegName  DEV  \
# 81  Immigrants  Foreigners   Iran   935     Asia  5501  Southern Asia  902
#
#                DevName  1980  ...  2004  2005  2006  2007  2008  2009  2010  \
# 81  Developing regions  1172  ...  6348  5837  7480  6974  6475  6580  7477
#
#     2011  2012   2013
# 81  7479  7534  11291
#
# [1 rows x 43 columns]

# %%
df_world_pop.head()
# Out:
#        Country Country Code        1980        1981        1982        1983  \
# 0        Aruba          ABW     60096.0     60567.0     61345.0     62201.0
# 1  Afghanistan          AFG  13248370.0  13053954.0  12749645.0  12389269.0
# 2       Angola          AGO   8929900.0   9244507.0   9582156.0   9931562.0
# 3      Albania          ALB   2671997.0   2726056.0   2784278.0   2843960.0
# 4      Andorra          AND     36067.0     37500.0     39114.0     40867.0
#
#          1984        1985        1986        1987  ...        2004  \
# 0     62836.0     63026.0     62644.0     61833.0  ...     98737.0
# 1  12047115.0  11783050.0  11601041.0  11502761.0  ...  24118979.0
# 2  10277321.0  10609042.0  10921037.0  11218268.0  ...  18865716.0
# 3   2904429.0   2964762.0   3022635.0   3083605.0  ...   3026939.0
# 4     42706.0     44600.0     46517.0     48455.0  ...     76244.0
#
#          2005        2006        2007        2008        2009        2010  \
# 0    100031.0    100832.0    101220.0    101353.0    101453.0    101669.0
# 1  25070798.0  25893450.0  26616792.0  27294031.0  28004331.0  28803167.0
# 2  19552542.0  20262399.0  20997687.0  21759420.0  22549547.0  23369131.0
# 3   3011487.0   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0
# 4     78867.0     80991.0     82683.0     83861.0     84462.0     84449.0
#
#          2011        2012        2013
# 0    102053.0    102577.0    103187.0
# 1  29708599.0  30696958.0  31731688.0
# 2  24218565.0  25096150.0  25998340.0
# 3   2905195.0   2900401.0   2895092.0
# 4     83751.0     82431.0     80788.0
#
# [5 rows x 36 columns]

# %%
df_names.head()
# Out:
#                 Country   ID
# 0           Afghanistan  AFG
# 1                Angola  AGO
# 2               Albania  ALB
# 3  United Arab Emirates  ARE
# 4             Argentina  ARG

# %%
pop_missing = list(set(df_names.ID) - set(df_world_pop['Country Code']))
len(pop_missing)
# Out:
# 6

# %%
not_in_world_pop = list(set(df_names.ID) - set(df_world_pop['Country Code']))
not_in_world_pop
# Out:
# ['TWN', 'FLK', 'ATA', '-99', 'ATF', 'SDS']

# %%
df_names[df_names.ID.isin(not_in_world_pop)]
# Out:
#                                  Country   ID
# 6                             Antarctica  ATA
# 7    French Southern and Antarctic Lands  ATF
# 38                       Northern Cyprus  -99
# 54                      Falkland Islands  FLK
# 88                                Kosovo  -99
# 136                       Western Sahara  -99
# 139                          South Sudan  SDS
# 144                           Somaliland  -99
# 162                               Taiwan  TWN

# %%
# 04/15/19 1:45
